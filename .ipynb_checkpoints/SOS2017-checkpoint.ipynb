# %% [markdown]
# #### Putting It All Together
#
# As you might have guessed from the last notebook, using all of the variables was allowing you to drastically overfit the training data.  This was great for looking good in terms of your Rsquared on these points.  However, this was not great in terms of how well you were able to predict on the test data.
#
# We will start where we left off in the last notebook.  First read in the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

# %%
# Display all rows of dataframes
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('./survey-results-public.csv')
df.head().T
# Out:
#                                                                                   0  \
# Respondent                                                                        1
# Professional                                                                Student
# ProgramHobby                                                              Yes, both
# Country                                                               United States
# University                                                                       No
# EmploymentStatus                             Not employed, and not looking for work
# FormalEducation                                                    Secondary school
# MajorUndergrad                                                                  NaN
# HomeRemote                                                                      NaN
# CompanySize                                                                     NaN
# CompanyType                                                                     NaN
# YearsProgram                                                           2 to 3 years
# YearsCodedJob                                                                   NaN
# YearsCodedJobPast                                                               NaN
# DeveloperType                                                                   NaN
# WebDeveloperType                                                                NaN
# MobileDeveloperType                                                             NaN
# NonDeveloperType                                                                NaN
# CareerSatisfaction                                                              NaN
# JobSatisfaction                                                                 NaN
# ExCoderReturn                                                                   NaN
# ExCoderNotForMe                                                                 NaN
# ExCoderBalance                                                                  NaN
# ExCoder10Years                                                                  NaN
# ExCoderBelonged                                                                 NaN
# ExCoderSkills                                                                   NaN
# ExCoderWillNotCode                                                              NaN
# ExCoderActive                                                                   NaN
# PronounceGIF                                           With a soft "g," like "jiff"
# ProblemSolving                                                       Strongly agree
# BuildingThings                                                       Strongly agree
# LearningNewTech                                                               Agree
# BoringDetails                                                              Disagree
# JobSecurity                                                          Strongly agree
# DiversityImportant                                                            Agree
# AnnoyingUI                                                                    Agree
# FriendsDevelopers                                                          Disagree
# RightWrongWay                                                        Somewhat agree
# UnderstandComputers                                                        Disagree
# SeriousWork                                                          Strongly agree
# InvestTimeTools                                                      Strongly agree
# WorkPayCare                                                       Strongly disagree
# KinshipDevelopers                                                             Agree
# ChallengeMyself                                                               Agree
# CompetePeers                                                               Disagree
# ChangeWorld                                                                   Agree
# JobSeekingStatus                  I'm not actively looking, but I am open to new...
# HoursPerWeek                                                                    0.0
# LastNewJob                                                    Not applicable/ never
# AssessJobIndustry                                                    Very important
# AssessJobRole                                                        Very important
# AssessJobExp                                                              Important
# AssessJobDept                                                        Very important
# AssessJobTech                                                        Very important
# AssessJobProjects                                                    Very important
# AssessJobCompensation                                                     Important
# AssessJobOffice                                                      Very important
# AssessJobCommute                                                     Very important
# AssessJobRemote                                                      Very important
# AssessJobLeaders                                                     Very important
# AssessJobProfDevel                                                   Very important
# AssessJobDiversity                                               Somewhat important
# AssessJobProduct                                                 Not very important
# AssessJobFinances                                                Somewhat important
# ImportantBenefits                  Stock options; Vacation/days off; Remote options
# ClickyKeys                                                                      Yes
# JobProfile                                                                    Other
# ResumePrompted                                                                  NaN
# LearnedHiring                                                                   NaN
# ImportantHiringAlgorithms                                                 Important
# ImportantHiringTechExp                                                    Important
# ImportantHiringCommunication                                              Important
# ImportantHiringOpenSource                                        Somewhat important
# ImportantHiringPMExp                                                      Important
# ImportantHiringCompanies                                         Not very important
# ImportantHiringTitles                                            Not very important
# ImportantHiringEducation                                       Not at all important
# ImportantHiringRep                                               Somewhat important
# ImportantHiringGettingThingsDone                                     Very important
# Currency                                                                        NaN
# Overpaid                                                                        NaN
# TabsSpaces                                                                     Tabs
# EducationImportant                                                              NaN
# EducationTypes                             Online course; Open source contributions
# SelfTaughtTypes                                                                 NaN
# TimeAfterBootcamp                                                               NaN
# CousinEducation                                                                 NaN
# WorkStart                                                                   6:00 AM
# HaveWorkedLanguage                                                            Swift
# WantWorkLanguage                                                              Swift
# HaveWorkedFramework                                                             NaN
# WantWorkFramework                                                               NaN
# HaveWorkedDatabase                                                              NaN
# WantWorkDatabase                                                                NaN
# HaveWorkedPlatform                                                              iOS
# WantWorkPlatform                                                                iOS
# IDE                                                                     Atom; Xcode
# AuditoryEnvironment                                              Turn on some music
# Methodology                                                                     NaN
# VersionControl                                                                  NaN
# CheckInCode                                                                     NaN
# ShipIt                                                                          NaN
# OtherPeoplesCode                                                                NaN
# ProjectManagement                                                               NaN
# EnjoyDebugging                                                                  NaN
# InTheZone                                                                       NaN
# DifficultCommunication                                                          NaN
# CollaborateRemote                                                               NaN
# MetricAssess                                                                    NaN
# EquipmentSatisfiedMonitors                                       Somewhat satisfied
# EquipmentSatisfiedCPU                                            Not very satisfied
# EquipmentSatisfiedRAM                                          Not at all satisfied
# EquipmentSatisfiedStorage                                            Very satisfied
# EquipmentSatisfiedRW                                                      Satisfied
# InfluenceInternet                                                Not very satisfied
# InfluenceWorkstation                                                            NaN
# InfluenceHardware                                                               NaN
# InfluenceServers                                                                NaN
# InfluenceTechStack                                                              NaN
# InfluenceDeptTech                                                               NaN
# InfluenceVizTools                                                               NaN
# InfluenceDatabase                                                               NaN
# InfluenceCloud                                                                  NaN
# InfluenceConsultants                                                            NaN
# InfluenceRecruitment                                                            NaN
# InfluenceCommunication                                                          NaN
# StackOverflowDescribes            I have created a CV or Developer Story on Stac...
# StackOverflowSatisfaction                                                       9.0
# StackOverflowDevices                                               Desktop; iOS app
# StackOverflowFoundAnswer                                    At least once each week
# StackOverflowCopiedCode                                         Haven't done at all
# StackOverflowJobListing                                               Once or twice
# StackOverflowCompanyPage                                        Haven't done at all
# StackOverflowJobSearch                                          Haven't done at all
# StackOverflowNewQuestion                                              Several times
# StackOverflowAnswer                                                   Several times
# StackOverflowMetaChat                                                 Once or twice
# StackOverflowAdsRelevant                                             Somewhat agree
# StackOverflowAdsDistracting                                       Strongly disagree
# StackOverflowModeration                                           Strongly disagree
# StackOverflowCommunity                                               Strongly agree
# StackOverflowHelpful                                                          Agree
# StackOverflowBetter                                                  Strongly agree
# StackOverflowWhatDo                                                  Strongly agree
# StackOverflowMakeMoney                                            Strongly disagree
# Gender                                                                         Male
# HighestEducationParents                                                 High school
# Race                                                   White or of European descent
# SurveyLong                                                        Strongly disagree
# QuestionsInteresting                                                 Strongly agree
# QuestionsConfusing                                                         Disagree
# InterestedAnswers                                                    Strongly agree
# Salary                                                                          NaN
# ExpectedSalary                                                                  NaN
#
#                                                                                   1  \
# Respondent                                                                        2
# Professional                                                                Student
# ProgramHobby                                                              Yes, both
# Country                                                              United Kingdom
# University                                                           Yes, full-time
# EmploymentStatus                                                 Employed part-time
# FormalEducation                   Some college/university study without earning ...
# MajorUndergrad                             Computer science or software engineering
# HomeRemote                                    More than half, but not all, the time
# CompanySize                                                      20 to 99 employees
# CompanyType                       Privately-held limited company, not in startup...
# YearsProgram                                                          9 to 10 years
# YearsCodedJob                                                                   NaN
# YearsCodedJobPast                                                               NaN
# DeveloperType                                                                   NaN
# WebDeveloperType                                                                NaN
# MobileDeveloperType                                                             NaN
# NonDeveloperType                                                                NaN
# CareerSatisfaction                                                              NaN
# JobSatisfaction                                                                 NaN
# ExCoderReturn                                                                   NaN
# ExCoderNotForMe                                                                 NaN
# ExCoderBalance                                                                  NaN
# ExCoder10Years                                                                  NaN
# ExCoderBelonged                                                                 NaN
# ExCoderSkills                                                                   NaN
# ExCoderWillNotCode                                                              NaN
# ExCoderActive                                                                   NaN
# PronounceGIF                                           With a hard "g," like "gift"
# ProblemSolving                                                                  NaN
# BuildingThings                                                                  NaN
# LearningNewTech                                                                 NaN
# BoringDetails                                                                   NaN
# JobSecurity                                                                     NaN
# DiversityImportant                                                              NaN
# AnnoyingUI                                                                      NaN
# FriendsDevelopers                                                               NaN
# RightWrongWay                                                                   NaN
# UnderstandComputers                                                             NaN
# SeriousWork                                                                     NaN
# InvestTimeTools                                                                 NaN
# WorkPayCare                                                                     NaN
# KinshipDevelopers                                                               NaN
# ChallengeMyself                                                                 NaN
# CompetePeers                                                                    NaN
# ChangeWorld                                                                     NaN
# JobSeekingStatus                                                                NaN
# HoursPerWeek                                                                    NaN
# LastNewJob                                                                      NaN
# AssessJobIndustry                                                               NaN
# AssessJobRole                                                                   NaN
# AssessJobExp                                                                    NaN
# AssessJobDept                                                                   NaN
# AssessJobTech                                                                   NaN
# AssessJobProjects                                                               NaN
# AssessJobCompensation                                                           NaN
# AssessJobOffice                                                                 NaN
# AssessJobCommute                                                                NaN
# AssessJobRemote                                                                 NaN
# AssessJobLeaders                                                                NaN
# AssessJobProfDevel                                                              NaN
# AssessJobDiversity                                                              NaN
# AssessJobProduct                                                                NaN
# AssessJobFinances                                                               NaN
# ImportantBenefits                                                               NaN
# ClickyKeys                                                                       No
# JobProfile                                                                    Other
# ResumePrompted                                                                  NaN
# LearnedHiring                                                        Some other way
# ImportantHiringAlgorithms                                                 Important
# ImportantHiringTechExp                                                    Important
# ImportantHiringCommunication                                              Important
# ImportantHiringOpenSource                                                 Important
# ImportantHiringPMExp                                             Somewhat important
# ImportantHiringCompanies                                         Somewhat important
# ImportantHiringTitles                                            Not very important
# ImportantHiringEducation                                         Somewhat important
# ImportantHiringRep                                               Not very important
# ImportantHiringGettingThingsDone                                     Very important
# Currency                                                British pounds sterling (£)
# Overpaid                                                                        NaN
# TabsSpaces                                                                   Spaces
# EducationImportant                                                              NaN
# EducationTypes                    Online course; Self-taught; Hackathon; Open so...
# SelfTaughtTypes                   Official documentation; Stack Overflow Q&A; Other
# TimeAfterBootcamp                                                               NaN
# CousinEducation                                                                 NaN
# WorkStart                                                                  10:00 AM
# HaveWorkedLanguage                                    JavaScript; Python; Ruby; SQL
# WantWorkLanguage                                            Java; Python; Ruby; SQL
# HaveWorkedFramework                                                       .NET Core
# WantWorkFramework                                                         .NET Core
# HaveWorkedDatabase                                                    MySQL; SQLite
# WantWorkDatabase                                                      MySQL; SQLite
# HaveWorkedPlatform                                        Amazon Web Services (AWS)
# WantWorkPlatform                  Linux Desktop; Raspberry Pi; Amazon Web Servic...
# IDE                               Atom; Notepad++; Vim; PyCharm; RubyMine; Visua...
# AuditoryEnvironment               Put on some ambient sounds (e.g. whale songs, ...
# Methodology                                                                     NaN
# VersionControl                                                                  Git
# CheckInCode                                                    Multiple times a day
# ShipIt                                                                        Agree
# OtherPeoplesCode                                                           Disagree
# ProjectManagement                                                 Strongly disagree
# EnjoyDebugging                                                                Agree
# InTheZone                                                            Somewhat agree
# DifficultCommunication                                                     Disagree
# CollaborateRemote                                                 Strongly disagree
# MetricAssess                      Customer satisfaction; On time/in budget; Peer...
# EquipmentSatisfiedMonitors                                       Not very satisfied
# EquipmentSatisfiedCPU                                                     Satisfied
# EquipmentSatisfiedRAM                                                     Satisfied
# EquipmentSatisfiedStorage                                                 Satisfied
# EquipmentSatisfiedRW                                             Somewhat satisfied
# InfluenceInternet                                                         Satisfied
# InfluenceWorkstation                                            No influence at all
# InfluenceHardware                                               No influence at all
# InfluenceServers                                                No influence at all
# InfluenceTechStack                                              No influence at all
# InfluenceDeptTech                                               No influence at all
# InfluenceVizTools                                               No influence at all
# InfluenceDatabase                                               No influence at all
# InfluenceCloud                                                  No influence at all
# InfluenceConsultants                                            No influence at all
# InfluenceRecruitment                                            No influence at all
# InfluenceCommunication                                          No influence at all
# StackOverflowDescribes            I have created a CV or Developer Story on Stac...
# StackOverflowSatisfaction                                                       8.0
# StackOverflowDevices              Desktop; iOS browser; iOS app; Android browser...
# StackOverflowFoundAnswer                                              Several times
# StackOverflowCopiedCode                                               Several times
# StackOverflowJobListing                                               Once or twice
# StackOverflowCompanyPage                                              Once or twice
# StackOverflowJobSearch                                                Once or twice
# StackOverflowNewQuestion                                        Haven't done at all
# StackOverflowAnswer                                                   Several times
# StackOverflowMetaChat                                       At least once each week
# StackOverflowAdsRelevant                                                   Disagree
# StackOverflowAdsDistracting                                       Strongly disagree
# StackOverflowModeration                                           Strongly disagree
# StackOverflowCommunity                                               Strongly agree
# StackOverflowHelpful                                                          Agree
# StackOverflowBetter                                                  Strongly agree
# StackOverflowWhatDo                                                  Strongly agree
# StackOverflowMakeMoney                                            Strongly disagree
# Gender                                                                         Male
# HighestEducationParents                                           A master's degree
# Race                                                   White or of European descent
# SurveyLong                                                           Somewhat agree
# QuestionsInteresting                                                 Somewhat agree
# QuestionsConfusing                                                         Disagree
# InterestedAnswers                                                    Strongly agree
# Salary                                                                          NaN
# ExpectedSalary                                                              37500.0
#
#                                                                                   2  \
# Respondent                                                                        3
# Professional                                                 Professional developer
# ProgramHobby                                                              Yes, both
# Country                                                              United Kingdom
# University                                                                       No
# EmploymentStatus                                                 Employed full-time
# FormalEducation                                                   Bachelor's degree
# MajorUndergrad                             Computer science or software engineering
# HomeRemote                        Less than half the time, but at least one day ...
# CompanySize                                                10,000 or more employees
# CompanyType                                             Publicly-traded corporation
# YearsProgram                                                       20 or more years
# YearsCodedJob                                                      20 or more years
# YearsCodedJobPast                                                               NaN
# DeveloperType                                                                 Other
# WebDeveloperType                                                                NaN
# MobileDeveloperType                                                             NaN
# NonDeveloperType                                                                NaN
# CareerSatisfaction                                                              8.0
# JobSatisfaction                                                                 9.0
# ExCoderReturn                                                                   NaN
# ExCoderNotForMe                                                                 NaN
# ExCoderBalance                                                                  NaN
# ExCoder10Years                                                                  NaN
# ExCoderBelonged                                                                 NaN
# ExCoderSkills                                                                   NaN
# ExCoderWillNotCode                                                              NaN
# ExCoderActive                                                                   NaN
# PronounceGIF                                           With a hard "g," like "gift"
# ProblemSolving                                                       Strongly agree
# BuildingThings                                                       Strongly agree
# LearningNewTech                                                      Strongly agree
# BoringDetails                                                        Somewhat agree
# JobSecurity                                                                   Agree
# DiversityImportant                                                   Strongly agree
# AnnoyingUI                                                                    Agree
# FriendsDevelopers                                                    Somewhat agree
# RightWrongWay                                                              Disagree
# UnderstandComputers                                                        Disagree
# SeriousWork                                                                   Agree
# InvestTimeTools                                                      Somewhat agree
# WorkPayCare                                                                Disagree
# KinshipDevelopers                                                    Somewhat agree
# ChallengeMyself                                                               Agree
# CompetePeers                                                               Disagree
# ChangeWorld                                                                   Agree
# JobSeekingStatus                                                                NaN
# HoursPerWeek                                                                    NaN
# LastNewJob                                                                      NaN
# AssessJobIndustry                                                               NaN
# AssessJobRole                                                                   NaN
# AssessJobExp                                                                    NaN
# AssessJobDept                                                                   NaN
# AssessJobTech                                                                   NaN
# AssessJobProjects                                                               NaN
# AssessJobCompensation                                                           NaN
# AssessJobOffice                                                                 NaN
# AssessJobCommute                                                                NaN
# AssessJobRemote                                                                 NaN
# AssessJobLeaders                                                                NaN
# AssessJobProfDevel                                                              NaN
# AssessJobDiversity                                                              NaN
# AssessJobProduct                                                                NaN
# AssessJobFinances                                                               NaN
# ImportantBenefits                                                               NaN
# ClickyKeys                                                                      Yes
# JobProfile                                                                      NaN
# ResumePrompted                                                                  NaN
# LearnedHiring                                                                   NaN
# ImportantHiringAlgorithms                                                       NaN
# ImportantHiringTechExp                                                          NaN
# ImportantHiringCommunication                                                    NaN
# ImportantHiringOpenSource                                                       NaN
# ImportantHiringPMExp                                                            NaN
# ImportantHiringCompanies                                                        NaN
# ImportantHiringTitles                                                           NaN
# ImportantHiringEducation                                                        NaN
# ImportantHiringRep                                                              NaN
# ImportantHiringGettingThingsDone                                                NaN
# Currency                                                British pounds sterling (£)
# Overpaid                                             Neither underpaid nor overpaid
# TabsSpaces                                                                   Spaces
# EducationImportant                                               Not very important
# EducationTypes                    Self-taught; Coding competition; Hackathon; Op...
# SelfTaughtTypes                   Official documentation; Trade book; Textbook; ...
# TimeAfterBootcamp                                                               NaN
# CousinEducation                                                                 NaN
# WorkStart                                                                   9:00 AM
# HaveWorkedLanguage                                                Java; PHP; Python
# WantWorkLanguage                                                    C; Python; Rust
# HaveWorkedFramework                                                             NaN
# WantWorkFramework                                                               NaN
# HaveWorkedDatabase                                                            MySQL
# WantWorkDatabase                                                                NaN
# HaveWorkedPlatform                                                              NaN
# WantWorkPlatform                                                                NaN
# IDE                                                     Sublime Text; Vim; IntelliJ
# AuditoryEnvironment                                              Turn on some music
# Methodology                               Agile; Lean; Scrum; Extreme; Pair; Kanban
# VersionControl                                                            Mercurial
# CheckInCode                                                    Multiple times a day
# ShipIt                                                                        Agree
# OtherPeoplesCode                                                           Disagree
# ProjectManagement                                                          Disagree
# EnjoyDebugging                                                                Agree
# InTheZone                                                                     Agree
# DifficultCommunication                                                     Disagree
# CollaborateRemote                                                    Somewhat agree
# MetricAssess                      Customer satisfaction; Benchmarked product per...
# EquipmentSatisfiedMonitors                                           Very satisfied
# EquipmentSatisfiedCPU                                            Somewhat satisfied
# EquipmentSatisfiedRAM                                                     Satisfied
# EquipmentSatisfiedStorage                                                 Satisfied
# EquipmentSatisfiedRW                                             Somewhat satisfied
# InfluenceInternet                                                    Very satisfied
# InfluenceWorkstation                                             A lot of influence
# InfluenceHardware                                                    Some influence
# InfluenceServers                                                     Some influence
# InfluenceTechStack                                                   Some influence
# InfluenceDeptTech                                                A lot of influence
# InfluenceVizTools                                                    Some influence
# InfluenceDatabase                                                    Some influence
# InfluenceCloud                                                       Some influence
# InfluenceConsultants                                                 Some influence
# InfluenceRecruitment                                                 Some influence
# InfluenceCommunication                                               Some influence
# StackOverflowDescribes            I have created a CV or Developer Story on Stac...
# StackOverflowSatisfaction                                                       8.0
# StackOverflowDevices                                  Desktop; iOS browser; iOS app
# StackOverflowFoundAnswer                                              Once or twice
# StackOverflowCopiedCode                                         Haven't done at all
# StackOverflowJobListing                                         Haven't done at all
# StackOverflowCompanyPage                                        Haven't done at all
# StackOverflowJobSearch                                          Haven't done at all
# StackOverflowNewQuestion                                        Haven't done at all
# StackOverflowAnswer                                          At least once each day
# StackOverflowMetaChat                                        At least once each day
# StackOverflowAdsRelevant                                                   Disagree
# StackOverflowAdsDistracting                                                Disagree
# StackOverflowModeration                                           Strongly disagree
# StackOverflowCommunity                                               Strongly agree
# StackOverflowHelpful                                                          Agree
# StackOverflowBetter                                                           Agree
# StackOverflowWhatDo                                                           Agree
# StackOverflowMakeMoney                                                     Disagree
# Gender                                                                         Male
# HighestEducationParents                                       A professional degree
# Race                                                   White or of European descent
# SurveyLong                                                           Somewhat agree
# QuestionsInteresting                                                          Agree
# QuestionsConfusing                                                         Disagree
# InterestedAnswers                                                             Agree
# Salary                                                                     113750.0
# ExpectedSalary                                                                  NaN
#
#                                                                                   3  \
# Respondent                                                                        4
# Professional                      Professional non-developer who sometimes write...
# ProgramHobby                                                              Yes, both
# Country                                                               United States
# University                                                                       No
# EmploymentStatus                                                 Employed full-time
# FormalEducation                                                     Doctoral degree
# MajorUndergrad                        A non-computer-focused engineering discipline
# HomeRemote                        Less than half the time, but at least one day ...
# CompanySize                                                10,000 or more employees
# CompanyType                       Non-profit/non-governmental organization or pr...
# YearsProgram                                                         14 to 15 years
# YearsCodedJob                                                         9 to 10 years
# YearsCodedJobPast                                                               NaN
# DeveloperType                                                                   NaN
# WebDeveloperType                                                                NaN
# MobileDeveloperType                                                             NaN
# NonDeveloperType                                                     Data scientist
# CareerSatisfaction                                                              6.0
# JobSatisfaction                                                                 3.0
# ExCoderReturn                                                                   NaN
# ExCoderNotForMe                                                                 NaN
# ExCoderBalance                                                                  NaN
# ExCoder10Years                                                                  NaN
# ExCoderBelonged                                                                 NaN
# ExCoderSkills                                                                   NaN
# ExCoderWillNotCode                                                              NaN
# ExCoderActive                                                                   NaN
# PronounceGIF                                           With a soft "g," like "jiff"
# ProblemSolving                                                       Strongly agree
# BuildingThings                                                       Strongly agree
# LearningNewTech                                                      Strongly agree
# BoringDetails                                                              Disagree
# JobSecurity                                                          Somewhat agree
# DiversityImportant                                                            Agree
# AnnoyingUI                                                                    Agree
# FriendsDevelopers                                                             Agree
# RightWrongWay                                                        Somewhat agree
# UnderstandComputers                                               Strongly disagree
# SeriousWork                                                          Strongly agree
# InvestTimeTools                                                               Agree
# WorkPayCare                                                                Disagree
# KinshipDevelopers                                                    Strongly agree
# ChallengeMyself                                                      Strongly agree
# CompetePeers                                                         Somewhat agree
# ChangeWorld                                                                   Agree
# JobSeekingStatus                                    I am actively looking for a job
# HoursPerWeek                                                                    5.0
# LastNewJob                                                Between 2 and 4 years ago
# AssessJobIndustry                                                Somewhat important
# AssessJobRole                                                    Somewhat important
# AssessJobExp                                                     Somewhat important
# AssessJobDept                                                             Important
# AssessJobTech                                                             Important
# AssessJobProjects                                                    Very important
# AssessJobCompensation                                                     Important
# AssessJobOffice                                                      Very important
# AssessJobCommute                                                          Important
# AssessJobRemote                                                  Somewhat important
# AssessJobLeaders                                                 Not very important
# AssessJobProfDevel                                                   Very important
# AssessJobDiversity                                                        Important
# AssessJobProduct                                                     Very important
# AssessJobFinances                                                    Very important
# ImportantBenefits                 Stock options; Annual bonus; Health benefits; ...
# ClickyKeys                                                                      Yes
# JobProfile                                                          LinkedIn; Other
# ResumePrompted                                                                  NaN
# LearnedHiring                     A friend, family member, or former colleague t...
# ImportantHiringAlgorithms                                        Somewhat important
# ImportantHiringTechExp                                           Somewhat important
# ImportantHiringCommunication                                         Very important
# ImportantHiringOpenSource                                            Very important
# ImportantHiringPMExp                                             Somewhat important
# ImportantHiringCompanies                                         Somewhat important
# ImportantHiringTitles                                            Not very important
# ImportantHiringEducation                                         Not very important
# ImportantHiringRep                                                        Important
# ImportantHiringGettingThingsDone                                     Very important
# Currency                                                                        NaN
# Overpaid                                                                        NaN
# TabsSpaces                                                                   Spaces
# EducationImportant                                                              NaN
# EducationTypes                                                                  NaN
# SelfTaughtTypes                                                                 NaN
# ...
# InfluenceRecruitment                                                            NaN
# InfluenceCommunication                                                          NaN
# StackOverflowDescribes            I have created a CV or Developer Story on Stac...
# StackOverflowSatisfaction                                                      10.0
# StackOverflowDevices                                  Desktop; iOS browser; iOS app
# StackOverflowFoundAnswer                                    At least once each week
# StackOverflowCopiedCode                                               Several times
# StackOverflowJobListing                                     At least once each week
# StackOverflowCompanyPage                                              Several times
# StackOverflowJobSearch                                      At least once each week
# StackOverflowNewQuestion                                              Several times
# StackOverflowAnswer                                          At least once each day
# StackOverflowMetaChat                                        At least once each day
# StackOverflowAdsRelevant                                                      Agree
# StackOverflowAdsDistracting                                       Strongly disagree
# StackOverflowModeration                                           Strongly disagree
# StackOverflowCommunity                                               Strongly agree
# StackOverflowHelpful                                                 Strongly agree
# StackOverflowBetter                                                           Agree
# StackOverflowWhatDo                                                  Strongly agree
# StackOverflowMakeMoney                                                     Disagree
# Gender                                                                         Male
# HighestEducationParents                                           A doctoral degree
# Race                                                   White or of European descent
# SurveyLong                                                                    Agree
# QuestionsInteresting                                                          Agree
# QuestionsConfusing                                                   Somewhat agree
# InterestedAnswers                                                    Strongly agree
# Salary                                                                          NaN
# ExpectedSalary                                                                  NaN
#
#                                                                                   4
# Respondent                                                                        5
# Professional                                                 Professional developer
# ProgramHobby                                              Yes, I program as a hobby
# Country                                                                 Switzerland
# University                                                                       No
# EmploymentStatus                                                 Employed full-time
# FormalEducation                                                     Master's degree
# MajorUndergrad                             Computer science or software engineering
# HomeRemote                                                                    Never
# CompanySize                                                      10 to 19 employees
# CompanyType                       Privately-held limited company, not in startup...
# YearsProgram                                                       20 or more years
# YearsCodedJob                                                        10 to 11 years
# YearsCodedJobPast                                                               NaN
# DeveloperType                     Mobile developer; Graphics programming; Deskto...
# WebDeveloperType                                                                NaN
# MobileDeveloperType                                                             NaN
# NonDeveloperType                                                                NaN
# CareerSatisfaction                                                              6.0
# JobSatisfaction                                                                 8.0
# ExCoderReturn                                                                   NaN
# ExCoderNotForMe                                                                 NaN
# ExCoderBalance                                                                  NaN
# ExCoder10Years                                                                  NaN
# ExCoderBelonged                                                                 NaN
# ExCoderSkills                                                                   NaN
# ExCoderWillNotCode                                                              NaN
# ExCoderActive                                                                   NaN
# PronounceGIF                                           With a soft "g," like "jiff"
# ProblemSolving                                                                  NaN
# BuildingThings                                                                  NaN
# LearningNewTech                                                                 NaN
# BoringDetails                                                                   NaN
# JobSecurity                                                                     NaN
# DiversityImportant                                                              NaN
# AnnoyingUI                                                                      NaN
# FriendsDevelopers                                                               NaN
# RightWrongWay                                                                   NaN
# UnderstandComputers                                                             NaN
# SeriousWork                                                                     NaN
# InvestTimeTools                                                                 NaN
# WorkPayCare                                                                     NaN
# KinshipDevelopers                                                               NaN
# ChallengeMyself                                                                 NaN
# CompetePeers                                                                    NaN
# ChangeWorld                                                                     NaN
# JobSeekingStatus                                                                NaN
# HoursPerWeek                                                                    NaN
# LastNewJob                                                                      NaN
# AssessJobIndustry                                                               NaN
# AssessJobRole                                                                   NaN
# AssessJobExp                                                                    NaN
# AssessJobDept                                                                   NaN
# AssessJobTech                                                                   NaN
# AssessJobProjects                                                               NaN
# AssessJobCompensation                                                           NaN
# AssessJobOffice                                                                 NaN
# AssessJobCommute                                                                NaN
# AssessJobRemote                                                                 NaN
# AssessJobLeaders                                                                NaN
# AssessJobProfDevel                                                              NaN
# AssessJobDiversity                                                              NaN
# AssessJobProduct                                                                NaN
# AssessJobFinances                                                               NaN
# ImportantBenefits                                                               NaN
# ClickyKeys                                                                      NaN
# JobProfile                                                                      NaN
# ResumePrompted                                                                  NaN
# LearnedHiring                                                                   NaN
# ImportantHiringAlgorithms                                                       NaN
# ImportantHiringTechExp                                                          NaN
# ImportantHiringCommunication                                                    NaN
# ImportantHiringOpenSource                                                       NaN
# ImportantHiringPMExp                                                            NaN
# ImportantHiringCompanies                                                        NaN
# ImportantHiringTitles                                                           NaN
# ImportantHiringEducation                                                        NaN
# ImportantHiringRep                                                              NaN
# ImportantHiringGettingThingsDone                                                NaN
# Currency                                                                        NaN
# Overpaid                                                                        NaN
# TabsSpaces                                                                      NaN
# EducationImportant                                                              NaN
# EducationTypes                                                                  NaN
# SelfTaughtTypes                                                                 NaN
# TimeAfterBootcamp                                                               NaN
# CousinEducation                                                                 NaN
# WorkStart                                                                       NaN
# HaveWorkedLanguage                                                              NaN
# WantWorkLanguage                                                                NaN
# HaveWorkedFramework                                                             NaN
# WantWorkFramework                                                               NaN
# HaveWorkedDatabase                                                              NaN
# WantWorkDatabase                                                                NaN
# HaveWorkedPlatform                                                              NaN
# WantWorkPlatform                                                                NaN
# IDE                                                                             NaN
# AuditoryEnvironment                                                             NaN
# Methodology                                                                     NaN
# VersionControl                                                                  NaN
# CheckInCode                                                                     NaN
# ShipIt                                                                          NaN
# OtherPeoplesCode                                                                NaN
# ProjectManagement                                                               NaN
# EnjoyDebugging                                                                  NaN
# InTheZone                                                                       NaN
# DifficultCommunication                                                          NaN
# CollaborateRemote                                                               NaN
# MetricAssess                                                                    NaN
# EquipmentSatisfiedMonitors                                                Satisfied
# EquipmentSatisfiedCPU                                                     Satisfied
# EquipmentSatisfiedRAM                                                     Satisfied
# EquipmentSatisfiedStorage                                                 Satisfied
# EquipmentSatisfiedRW                                                      Satisfied
# InfluenceInternet                                                         Satisfied
# InfluenceWorkstation                                                            NaN
# InfluenceHardware                                                               NaN
# InfluenceServers                                                                NaN
# InfluenceTechStack                                                              NaN
# InfluenceDeptTech                                                               NaN
# InfluenceVizTools                                                               NaN
# InfluenceDatabase                                                               NaN
# InfluenceCloud                                                                  NaN
# InfluenceConsultants                                                            NaN
# InfluenceRecruitment                                                            NaN
# InfluenceCommunication                                                          NaN
# StackOverflowDescribes                                                          NaN
# StackOverflowSatisfaction                                                       NaN
# StackOverflowDevices                                                            NaN
# StackOverflowFoundAnswer                                                        NaN
# StackOverflowCopiedCode                                                         NaN
# StackOverflowJobListing                                                         NaN
# StackOverflowCompanyPage                                                        NaN
# StackOverflowJobSearch                                                          NaN
# StackOverflowNewQuestion                                                        NaN
# StackOverflowAnswer                                                             NaN
# StackOverflowMetaChat                                                           NaN
# StackOverflowAdsRelevant                                                        NaN
# StackOverflowAdsDistracting                                                     NaN
# StackOverflowModeration                                                         NaN
# StackOverflowCommunity                                                          NaN
# StackOverflowHelpful                                                            NaN
# StackOverflowBetter                                                             NaN
# StackOverflowWhatDo                                                             NaN
# StackOverflowMakeMoney                                                          NaN
# Gender                                                                          NaN
# HighestEducationParents                                                         NaN
# Race                                                                            NaN
# SurveyLong                                                                      NaN
# QuestionsInteresting                                                            NaN
# QuestionsConfusing                                                              NaN
# InterestedAnswers                                                               NaN
# Salary                                                                          NaN
# ExpectedSalary                                                                  NaN

# %%
df['HaveWorkedFramework'].value_counts()
# Out:
# HaveWorkedFramework
# .NET Core                                                                          3201
# AngularJS                                                                          2267
# Node.js                                                                            2098
# AngularJS; Node.js                                                                 1846
# Node.js; React                                                                      945
# React                                                                               738
# AngularJS; .NET Core                                                                653
# AngularJS; Node.js; React                                                           615
# Firebase                                                                            575
# AngularJS; Node.js; .NET Core                                                       505
# Node.js; .NET Core                                                                  426
# AngularJS; Node.js; Cordova                                                         408
# Xamarin; .NET Core                                                                  362
# Xamarin                                                                             301
# AngularJS; Cordova                                                                  257
# Hadoop                                                                              255
# Hadoop; Spark                                                                       240
# Cordova                                                                             215
# Spark                                                                               185
# AngularJS; React                                                                    174
# AngularJS; Node.js; Firebase                                                        171
# Node.js; Cordova                                                                    152
# AngularJS; Node.js; React; .NET Core                                                127
# AngularJS; Node.js; React; Cordova                                                  120
# Node.js; React; .NET Core                                                           118
# Node.js; Firebase                                                                   118
# AngularJS; Node.js; React; Firebase                                                 112
# AngularJS; Firebase                                                                  99
# Node.js; React; Firebase                                                             93
# AngularJS; Node.js; Cordova; Firebase                                                93
# AngularJS; Node.js; Xamarin; .NET Core                                               93
# AngularJS; Xamarin; .NET Core                                                        87
# AngularJS; Node.js; Cordova; .NET Core                                               86
# React; .NET Core                                                                     86
# Node.js; Xamarin; .NET Core                                                          85
# AngularJS; Xamarin                                                                   74
# Node.js; React; Cordova                                                              71
# AngularJS; Node.js; React; Cordova; Firebase                                         68
# Node.js; Xamarin                                                                     66
# AngularJS; Cordova; .NET Core                                                        62
# Firebase; .NET Core                                                                  60
# AngularJS; Node.js; Xamarin                                                          50
# AngularJS; Node.js; Cordova; Xamarin; .NET Core                                      50
# AngularJS; Hadoop; Node.js                                                           44
# Hadoop; Node.js; Spark                                                               43
# AngularJS; Hadoop; Spark                                                             42
# Hadoop; Node.js                                                                      41
# Cordova; .NET Core                                                                   39
# React; Firebase                                                                      39
# AngularJS; Hadoop                                                                    37
# AngularJS; Cordova; Firebase                                                         33
# Hadoop; .NET Core                                                                    33
# Node.js; Cordova; .NET Core                                                          33
# Node.js; Spark                                                                       33
# AngularJS; Node.js; Firebase; .NET Core                                              33
# Cordova; Firebase                                                                    33
# AngularJS; React; .NET Core                                                          32
# AngularJS; Hadoop; Node.js; Spark                                                    32
# AngularJS; Spark                                                                     31
# AngularJS; Node.js; React; Xamarin; .NET Core                                        31
# AngularJS; Node.js; Spark                                                            30
# Cordova; Xamarin; .NET Core                                                          30
# AngularJS; React; Cordova                                                            25
# Node.js; Firebase; .NET Core                                                         23
# Node.js; Cordova; Firebase                                                           23
# Xamarin; Firebase                                                                    21
# AngularJS; Node.js; React; Cordova; .NET Core                                        21
# AngularJS; Node.js; Cordova; Xamarin                                                 21
# AngularJS; Node.js; React; Firebase; .NET Core                                       21
# AngularJS; Cordova; Xamarin; .NET Core                                               21
# React; Cordova                                                                       20
# Hadoop; Node.js; React                                                               19
# Cordova; Xamarin                                                                     19
# AngularJS; Node.js; Cordova; Firebase; .NET Core                                     19
# Node.js; React; Xamarin; .NET Core                                                   19
# AngularJS; Node.js; React; Xamarin                                                   18
# React; Spark                                                                         18
# Hadoop; Spark; .NET Core                                                             17
# AngularJS; Firebase; .NET Core                                                       17
# AngularJS; Hadoop; Node.js; React                                                    17
# Node.js; React; Firebase; .NET Core                                                  16
# Hadoop; React                                                                        16
# Node.js; React; Cordova; .NET Core                                                   16
# AngularJS; Cordova; Xamarin                                                          15
# AngularJS; Hadoop; Node.js; React; Spark; Cordova; Xamarin; Firebase; .NET Core      14
# React; Xamarin                                                                       14
# Node.js; React; Xamarin                                                              14
# AngularJS; React; Firebase                                                           13
# Xamarin; Firebase; .NET Core                                                         13
# Node.js; React; Spark                                                                13
# Hadoop; Node.js; .NET Core                                                           12
# AngularJS; Hadoop; Node.js; React; Spark                                             12
# AngularJS; Hadoop; Node.js; .NET Core                                                12
# AngularJS; React; Spark                                                              11
# Hadoop; Node.js; React; Spark                                                        11
# AngularJS; Node.js; Xamarin; Firebase; .NET Core                                     11
# React; Xamarin; .NET Core                                                            11
# Node.js; Cordova; Xamarin; .NET Core                                                 10
# AngularJS; Node.js; Xamarin; Firebase                                                10
# AngularJS; Hadoop; Node.js; Spark; .NET Core                                         10
# Node.js; Xamarin; Firebase; .NET Core                                                10
# AngularJS; Node.js; React; Cordova; Xamarin; .NET Core                               10
# Spark; .NET Core                                                                     10
# AngularJS; Node.js; Spark; .NET Core                                                 10
# Node.js; React; Cordova; Firebase                                                     9
# AngularJS; Hadoop; .NET Core                                                          9
# AngularJS; Node.js; Cordova; Xamarin; Firebase                                        9
# AngularJS; Node.js; React; Cordova; Firebase; .NET Core                               8
# Node.js; Cordova; Xamarin                                                             8
# AngularJS; React; Xamarin                                                             8
# Hadoop; Firebase                                                                      8
# AngularJS; Node.js; React; Spark                                                      8
# AngularJS; Node.js; React; Cordova; Xamarin                                           8
# Cordova; Firebase; .NET Core                                                          8
# Hadoop; React; Spark                                                                  8
# AngularJS; Hadoop; Node.js; React; Cordova                                            7
# Spark; Firebase                                                                       7
# Hadoop; Node.js; Spark; .NET Core                                                     7
# AngularJS; Node.js; Cordova; Xamarin; Firebase; .NET Core                             7
# Node.js; Xamarin; Firebase                                                            7
# AngularJS; Hadoop; React                                                              7
# AngularJS; Hadoop; React; Spark                                                       6
# AngularJS; Hadoop; Cordova                                                            6
# Node.js; React; Cordova; Xamarin                                                      6
# AngularJS; Xamarin; Firebase; .NET Core                                               6
# AngularJS; Node.js; Spark; Cordova                                                    6
# AngularJS; Node.js; React; Spark; Cordova                                             5
# Hadoop; Node.js; Xamarin; .NET Core                                                   5
# AngularJS; Hadoop; Node.js; Firebase                                                  5
# AngularJS; Hadoop; Node.js; Cordova                                                   5
# AngularJS; Hadoop; Node.js; React; .NET Core                                          5
# Node.js; Spark; .NET Core                                                             5
# AngularJS; Hadoop; Node.js; Spark; Firebase                                           5
# AngularJS; Node.js; Spark; Firebase                                                   5
# AngularJS; Node.js; React; Cordova; Xamarin; Firebase                                 5
# Hadoop; Spark; Cordova                                                                5
# AngularJS; Hadoop; Node.js; React; Firebase                                           5
# AngularJS; Spark; Cordova                                                             5
# AngularJS; Node.js; React; Cordova; Xamarin; Firebase; .NET Core                      5
# AngularJS; React; Xamarin; .NET Core                                                  5
# AngularJS; Node.js; React; Xamarin; Firebase                                          4
# AngularJS; Cordova; Xamarin; Firebase; .NET Core                                      4
# React; Cordova; Firebase                                                              4
# Node.js; React; Xamarin; Firebase                                                     4
# Hadoop; Node.js; Firebase                                                             4
# Node.js; Cordova; Xamarin; Firebase; .NET Core                                        4
# AngularJS; Hadoop; Node.js; Spark; Cordova; Firebase                                  4
# Hadoop; Node.js; Cordova                                                              4
# Node.js; React; Cordova; Xamarin; .NET Core                                           4
# AngularJS; Hadoop; Node.js; Cordova; Firebase                                         4
# AngularJS; Xamarin; Firebase                                                          4
# Hadoop; Xamarin; .NET Core                                                            4
# Hadoop; Cordova                                                                       4
# AngularJS; Node.js; React; Spark; Cordova; Firebase                                   4
# Hadoop; Node.js; Spark; Cordova                                                       4
# Hadoop; Spark; Firebase                                                               4
# AngularJS; Hadoop; Node.js; React; Cordova; Xamarin; .NET Core                        4
# AngularJS; Hadoop; Node.js; React; Spark; Firebase                                    4
# Spark; Cordova                                                                        3
# AngularJS; Spark; .NET Core                                                           3
# Hadoop; Xamarin                                                                       3
# AngularJS; Hadoop; Node.js; Spark; Cordova; Xamarin; .NET Core                        3
# React; Firebase; .NET Core                                                            3
# Cordova; Xamarin; Firebase; .NET Core                                                 3
# Hadoop; Node.js; React; Firebase                                                      3
# AngularJS; Hadoop; Node.js; React; Cordova; .NET Core                                 3
# Hadoop; Spark; Xamarin; .NET Core                                                     3
# Node.js; React; Xamarin; Firebase; .NET Core                                          3
# AngularJS; Node.js; Spark; Cordova; Firebase                                          3
# AngularJS; Hadoop; Firebase                                                           3
# AngularJS; React; Spark; Firebase                                                     3
# AngularJS; Hadoop; Node.js; React; Xamarin; .NET Core                                 3
# AngularJS; Node.js; React; Xamarin; Firebase; .NET Core                               3
# Node.js; Spark; Cordova                                                               3
# AngularJS; Hadoop; Node.js; React; Cordova; Firebase; .NET Core                       3
# Node.js; Spark; Firebase                                                              3
# AngularJS; Hadoop; Node.js; React; Spark; .NET Core                                   3
# AngularJS; React; Cordova; Xamarin                                                    3
# Spark; Xamarin                                                                        2
# AngularJS; Hadoop; Node.js; Cordova; Firebase; .NET Core                              2
# AngularJS; Hadoop; Node.js; Cordova; Xamarin; .NET Core                               2
# Hadoop; Spark; Xamarin                                                                2
# Cordova; Xamarin; Firebase                                                            2
# AngularJS; React; Cordova; .NET Core                                                  2
# AngularJS; Cordova; Xamarin; Firebase                                                 2
# AngularJS; Hadoop; Node.js; Spark; Xamarin; .NET Core                                 2
# Hadoop; Node.js; React; Cordova                                                       2
# Hadoop; React; Spark; Firebase                                                        2
# AngularJS; Hadoop; Node.js; React; Cordova; Xamarin; Firebase; .NET Core              2
# AngularJS; Hadoop; Node.js; React; Spark; Cordova; Xamarin; Firebase                  2
# React; Spark; .NET Core                                                               2
# AngularJS; Cordova; Firebase; .NET Core                                               2
# React; Cordova; .NET Core                                                             2
# AngularJS; Hadoop; Spark; Cordova                                                     2
# Hadoop; Spark; Firebase; .NET Core                                                    2
# AngularJS; Node.js; React; Spark; Xamarin; .NET Core                                  2
# AngularJS; React; Cordova; Xamarin; Firebase; .NET Core                               2
# AngularJS; React; Spark; .NET Core                                                    2
# Hadoop; Node.js; React; Spark; Cordova; .NET Core                                     2
# AngularJS; Hadoop; Spark; .NET Core                                                   2
# AngularJS; Node.js; React; Spark; Firebase                                            2
# AngularJS; Hadoop; Spark; Xamarin; .NET Core                                          2
# AngularJS; Hadoop; Node.js; React; Firebase; .NET Core                                2
# Node.js; Spark; Xamarin                                                               2
# Node.js; React; Spark; .NET Core                                                      2
# Hadoop; Node.js; React; .NET Core                                                     2
# AngularJS; Hadoop; Node.js; React; Cordova; Firebase                                  1
# Hadoop; Node.js; React; Spark; Firebase                                               1
# Hadoop; Node.js; React; Spark; Cordova                                                1
# Hadoop; Cordova; Firebase                                                             1
# Hadoop; Node.js; React; Spark; Cordova; Xamarin; Firebase; .NET Core                  1
# Hadoop; Node.js; React; Spark; Firebase; .NET Core                                    1
# AngularJS; Node.js; React; Spark; Cordova; Xamarin; .NET Core                         1
# Hadoop; Xamarin; Firebase                                                             1
# AngularJS; Hadoop; Node.js; Spark; Cordova                                            1
# AngularJS; Hadoop; Node.js; React; Spark; Cordova                                     1
# AngularJS; Spark; Xamarin; .NET Core                                                  1
# Hadoop; Node.js; React; Cordova; .NET Core                                            1
# AngularJS; Hadoop; Node.js; React; Spark; Xamarin; .NET Core                          1
# Hadoop; React; Spark; Firebase; .NET Core                                             1
# AngularJS; Node.js; Spark; Cordova; .NET Core                                         1
# Spark; Cordova; Firebase                                                              1
# Hadoop; Cordova; Xamarin; .NET Core                                                   1
# Hadoop; Cordova; .NET Core                                                            1
# React; Cordova; Xamarin; .NET Core                                                    1
# AngularJS; Hadoop; Node.js; React; Xamarin; Firebase; .NET Core                       1
# AngularJS; Hadoop; Cordova; Xamarin; Firebase                                         1
# AngularJS; Hadoop; Spark; Firebase                                                    1
# AngularJS; Hadoop; Cordova; .NET Core                                                 1
# Hadoop; Firebase; .NET Core                                                           1
# AngularJS; Hadoop; Node.js; Spark; Firebase; .NET Core                                1
# Hadoop; React; Cordova; Xamarin; Firebase; .NET Core                                  1
# AngularJS; Hadoop; Node.js; Cordova; Xamarin; Firebase                                1
# Spark; Cordova; Firebase; .NET Core                                                   1
# Hadoop; React; .NET Core                                                              1
# AngularJS; Hadoop; Node.js; React; Spark; Xamarin; Firebase                           1
# Hadoop; Node.js; Cordova; .NET Core                                                   1
# AngularJS; Node.js; Spark; Xamarin; Firebase; .NET Core                               1
# AngularJS; Hadoop; Node.js; Spark; Cordova; .NET Core                                 1
# AngularJS; React; Cordova; Firebase                                                   1
# Hadoop; Node.js; React; Xamarin; .NET Core                                            1
# AngularJS; Hadoop; React; Cordova                                                     1
# Node.js; Spark; Xamarin; .NET Core                                                    1
# AngularJS; Hadoop; React; .NET Core                                                   1
# Hadoop; Node.js; React; Cordova; Firebase                                             1
# AngularJS; Hadoop; Node.js; React; Spark; Cordova; Firebase                           1
# AngularJS; Hadoop; Node.js; Cordova; .NET Core                                        1
# AngularJS; Node.js; React; Spark; Cordova; Xamarin; Firebase                          1
# AngularJS; Spark; Firebase; .NET Core                                                 1
# AngularJS; Node.js; React; Spark; Cordova; Firebase; .NET Core                        1
# Hadoop; Spark; Xamarin; Firebase; .NET Core                                           1
# React; Xamarin; Firebase                                                              1
# Node.js; React; Spark; Xamarin                                                        1
# AngularJS; Hadoop; Xamarin                                                            1
# AngularJS; React; Xamarin; Firebase; .NET Core                                        1
# Hadoop; React; Cordova; Xamarin; Firebase                                             1
# AngularJS; Hadoop; Cordova; Firebase                                                  1
# AngularJS; Node.js; Spark; Xamarin; .NET Core                                         1
# Hadoop; React; Spark; .NET Core                                                       1
# React; Cordova; Xamarin                                                               1
# AngularJS; Hadoop; Cordova; Firebase; .NET Core                                       1
# Hadoop; Node.js; Cordova; Xamarin; Firebase; .NET Core                                1
# AngularJS; Hadoop; Node.js; Xamarin                                                   1
# AngularJS; Node.js; Spark; Firebase; .NET Core                                        1
# AngularJS; Node.js; React; Spark; Cordova; Xamarin; Firebase; .NET Core               1
# AngularJS; Hadoop; Firebase; .NET Core                                                1
# AngularJS; Spark; Firebase                                                            1
# AngularJS; Node.js; React; Spark; Xamarin                                             1
# AngularJS; Hadoop; Node.js; React; Cordova; Xamarin                                   1
# Node.js; Cordova; Firebase; .NET Core                                                 1
# Hadoop; Node.js; React; Spark; Xamarin; .NET Core                                     1
# React; Cordova; Firebase; .NET Core                                                   1
# Node.js; React; Spark; Xamarin; .NET Core                                             1
# AngularJS; Hadoop; Node.js; Spark; Xamarin                                            1
# Hadoop; Node.js; React; Spark; .NET Core                                              1
# AngularJS; Hadoop; Node.js; Spark; Cordova; Firebase; .NET Core                       1
# React; Spark; Cordova                                                                 1
# AngularJS; Hadoop; Node.js; React; Spark; Xamarin; Firebase; .NET Core                1
# AngularJS; Spark; Cordova; .NET Core                                                  1
# AngularJS; Hadoop; React; Firebase                                                    1
# AngularJS; Hadoop; Xamarin; .NET Core                                                 1
# Node.js; React; Cordova; Firebase; .NET Core                                          1
# AngularJS; Hadoop; React; Spark; Cordova; Xamarin; .NET Core                          1
# AngularJS; Hadoop; Node.js; Firebase; .NET Core                                       1
# AngularJS; React; Cordova; Xamarin; .NET Core                                         1
# Name: count, dtype: int64

# %%
research_columns = ['UnderstandComputers', 'SeriousWork', 'InvestTimeTools', 'ChallengeMyself',
                    'CompetePeers', 'ChangeWorld', 'HaveWorkedLanguage', 'WantWorkLanguage', 'HaveWorkedFramework',
                    'WantWorkFramework', 'HighestEducationParents']

# %%
def non_nan_barh(df, collist):
    # Calculate the non-NaN value ratio for each column

    if not collist:
        # Empty column list
        non_nan_ratio = df.notna().mean()
    else:
        non_nan_ratio = df[research_columns].notna().mean()
        
    nnr_index = non_nan_ratio.index
    non_nan_ratio = non_nan_ratio.iloc[::-1]
        
    # Create a horizontal bar graph
    plt.figure(figsize=(10, 30))
    non_nan_ratio.plot(kind='barh')  # Change to horizontal bar graph
    plt.title('Non-NaN Value Ratio for Each Column')
    plt.xlabel('Non-NaN Ratio')
    plt.ylabel('Columns')
    plt.xlim(0, 1)  # Set x-axis limits
    plt.grid(axis='x')
    plt.show()

    return
# Out:
#   Cell In[7], line 4
#     if collist not collist:
#                    ^
# SyntaxError: invalid syntax

# %%
non_nan_barh(df, [])

# %%
def clean_data(df):
    '''
    INPUT
    df - pandas dataframe 
    
    OUTPUT
    X - A matrix holding all of the variables you want to consider when predicting the response
    y - the corresponding response vector
    
    This function cleans df using the following steps to produce X and y:
    1. Drop all the rows with no salaries
    2. Create X as all the columns that are not the Salary column
    3. Create y as the Salary column
    4. Drop the Salary, Respondent, and the ExpectedSalary columns from X
    5. For each numeric variable in X, fill the column with the mean value of the column.
    6. Create dummy columns for all the categorical variables in X, drop the original columns
    '''
    # Drop rows with missing salary values
    df = df.dropna(subset=['Salary'], axis=0)
    y = df['Salary']
    
    #Drop respondent and expected salary columns
    df = df.drop(['Respondent', 'ExpectedSalary', 'Salary'], axis=1)
    
    # Fill numeric columns with the mean
    num_vars = df.select_dtypes(include=['float', 'int']).columns
    for col in num_vars:
        df[col].fillna((df[col].mean()), inplace=True)
        
    # Dummy the categorical variables
    cat_vars = df.select_dtypes(include=['object']).copy().columns
    for var in  cat_vars:
        # for each cat add dummy var, drop original column
        df = pd.concat([df.drop(var, axis=1), pd.get_dummies(df[var], prefix=var, prefix_sep='_', drop_first=True)], axis=1)
    
    X = df
    return X, y
    
#Use the function to create X and y
X, y = clean_data(df)
# Out:
# C:\Users\balbol\AppData\Local\Temp\1\ipykernel_19956\2328966347.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna((df[col].mean()), inplace=True)

# %% [raw]
# #cutoffs here pertains to the number of missing values allowed in the used columns.
# #Therefore, lower values for the cutoff provides more predictors in the model.
# cutoffs = [5000, 3500, 2500, 1000, 100, 50]
#
# r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)

# %%
print(X_train.shape[1]) #Number of columns
print(r2_scores_test[np.argmax(r2_scores_test)]) # The model we should implement test_r2
print(r2_scores_train[np.argmax(r2_scores_test)]) # The model we should implement train_r2

# %% [markdown]
# #### Question 5
#
# **5.** The default penalty on coefficients using linear regression in sklearn is a ridge (also known as an L2) penalty.  Because of this penalty, and that all the variables were normalized, we can look at the size of the coefficients in the model as an indication of the impact of each variable on the salary.  The larger the coefficient, the larger the expected impact on salary.
#
# Use the space below to take a look at the coefficients.  Then use the results to provide the **True** or **False** statements based on the data.

# %% [raw]
# def coef_weights(coefficients, X_train):
#     '''
#     INPUT:
#     coefficients - the coefficients of the linear model
#     X_train - the training data, so the column names can be used
#     OUTPUT:
#     coefs_df - a dataframe holding the coefficient, estimate, and abs(estimate)
#
#     Provides a dataframe that can be used to understand the most influential coefficients
#     in a linear model by providing the coefficient estimates along with the name of the
#     variable attached to the coefficient.
#     '''
#     coefs_df = pd.DataFrame()
#     coefs_df['est_int'] = X_train.columns
#     coefs_df['coefs'] = lm_model.coef_
#     coefs_df['abs_coefs'] = np.abs(lm_model.coef_)
#     coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
#     return coefs_df
#
# #Use the function
# coef_df = coef_weights(lm_model.coef_, X_train)
#
# #A quick look at the top results
# coef_df.head(20)

# %% [markdown]
# #### Congrats of some kind
#
# Congrats!  Hopefully this was a great review, or an eye opening experience about how to put the steps together for an analysis. In the next lesson, you will look at how take this and show it off to others so they can act on it.
